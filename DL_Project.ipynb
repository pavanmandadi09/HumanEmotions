# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
import os

import cv2

from zipfile import ZipFile



# 1. Unzip dataset.zip into the current working directory

with ZipFile("dataset.zip", 'r') as zip_ref:

    zip_ref.extractall()



# 2. Set dataset paths based on your structure

train_folder = "train"

test_folder = "test"

processed_data_path = "Processed_Data"



# 3. Create output directories if they don't exist

if not os.path.exists(processed_data_path):

    os.makedirs(processed_data_path)

    os.makedirs(os.path.join(processed_data_path, "train"))

    os.makedirs(os.path.join(processed_data_path, "test"))



IMG_SIZE = (224, 224)



# 4. Image preprocessing function

def preprocess_images(source_dir, target_dir, img_size=IMG_SIZE):

    emotions = os.listdir(source_dir)

    for emotion in emotions:

        emotion_path = os.path.join(source_dir, emotion)

        if not os.path.isdir(emotion_path):

            continue

        target_emotion_path = os.path.join(target_dir, emotion)

        if not os.path.exists(target_emotion_path):

            os.makedirs(target_emotion_path)

        for img_name in os.listdir(emotion_path):

            img_path = os.path.join(emotion_path, img_name)

            try:

                img = cv2.imread(img_path)

                if img is None:

                    continue

                img = cv2.resize(img, img_size)

                if len(img.shape) == 2:

                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                elif img.shape[2] == 4:

                    img = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)

                elif img.shape[2] == 1:

                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)

                target_img_path = os.path.join(target_emotion_path, img_name)

                cv2.imwrite(target_img_path, img)

            except Exception as e:

                print(f"Error processing {img_path}: {e}")

                continue



# 5. Run preprocessing on train and test

if os.path.exists(train_folder):

    print("Preprocessing training images...")

    preprocess_images(train_folder, os.path.join(processed_data_path, "train"))

else:

    print("Training folder not found!")



if os.path.exists(test_folder):

    print("Preprocessing testing images...")

    preprocess_images(test_folder, os.path.join(processed_data_path, "test"))

else:

    print("Testing folder not found!")



print("Preprocessing completed!")
# Out:
# Preprocessing training images...
# Preprocessing testing images...
# Preprocessing completed!

# %%
# Explore the processed dataset
def explore_dataset(dataset_path):
    emotions = os.listdir(dataset_path)
    print("Emotions:", emotions)

    for emotion in emotions:
        emotion_path = os.path.join(dataset_path, emotion)
        if os.path.isdir(emotion_path):
            num_images = len(os.listdir(emotion_path))
            print(f"{emotion}: {num_images} images")

            # Display sample image
            if num_images > 0:
                sample_img = os.listdir(emotion_path)[0]
                sample_img_path = os.path.join(emotion_path, sample_img)
                img = cv2.imread(sample_img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                plt.figure(figsize=(3, 3))
                plt.imshow(img)
                plt.title(f"{emotion} sample")
                plt.axis('off')
                plt.show()

print("Training dataset:")
explore_dataset(os.path.join(processed_data_path, "train"))

print("\nTesting dataset:")
explore_dataset(os.path.join(processed_data_path, "test"))
# Out:
# Training dataset:
# Emotions: ['fear', 'anger', 'Natural', 'joy']
# fear: 39 images
# anger: 59 images
# Natural: 147 images
# joy: 370 images
# Testing dataset:
# Emotions: ['fear', 'anger', 'Natural', 'joy']
# fear: 10 images
# anger: 15 images
# Natural: 37 images
# joy: 93 images

# %%
# Create data generators
batch_size = 32

# Data augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    validation_split=0.2  # Using 20% of training data for validation
)

# Only rescaling for validation and testing
test_datagen = ImageDataGenerator(rescale=1./255)

# Training data generator
train_generator = train_datagen.flow_from_directory(
    os.path.join(processed_data_path, "train"),
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

# Validation data generator
validation_generator = train_datagen.flow_from_directory(
    os.path.join(processed_data_path, "train"),
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Test data generator
test_generator = test_datagen.flow_from_directory(
    os.path.join(processed_data_path, "test"),
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Get class labels
class_labels = list(train_generator.class_indices.keys())
print("Class labels:", class_labels)
print("Number of classes:", len(class_labels))
# Out:
# Found 494 images belonging to 4 classes.
# Found 121 images belonging to 4 classes.
# Found 155 images belonging to 4 classes.
# Class labels: ['Natural', 'anger', 'fear', 'joy']
# Number of classes: 4

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# MobileNetV2 base model (pretrained on ImageNet)
mobileNet_base = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)
mobileNet_base.trainable = False  # Freeze base layers

# Add custom classifier on top
inputs = Input(shape=(224, 224, 3))
x = mobileNet_base(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
outputs = Dense(train_generator.num_classes, activation='softmax')(x)

mobileNet_model = Model(inputs, outputs)
mobileNet_model.summary()

mobileNet_model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = mobileNet_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=150
)
# Out:
# Found 615 images belonging to 4 classes.
# Found 155 images belonging to 4 classes.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,428,100 (9.26 MB)
#  Trainable params: 167,300 (653.52 KB)
#  Non-trainable params: 2,260,800 (8.62 MB)
# Epoch 1/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.2789 - loss: 2.3301 - val_accuracy: 0.1548 - val_loss: 1.5276
# Epoch 2/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.3145 - loss: 2.0532 - val_accuracy: 0.3806 - val_loss: 1.3387
# Epoch 3/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.4006 - loss: 1.8362 - val_accuracy: 0.5484 - val_loss: 1.1508
# Epoch 4/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.4030 - loss: 1.7114 - val_accuracy: 0.5677 - val_loss: 1.0913
# Epoch 5/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 387ms/step - accuracy: 0.3852 - loss: 1.7528 - val_accuracy: 0.5742 - val_loss: 1.0621
# Epoch 6/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.4613 - loss: 1.5247 - val_accuracy: 0.6129 - val_loss: 1.0107
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.4774 - loss: 1.5108 - val_accuracy: 0.6323 - val_loss: 0.9298
# Epoch 8/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.4632 - loss: 1.4162 - val_accuracy: 0.6645 - val_loss: 0.8907
# Epoch 9/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.5270 - loss: 1.2878 - val_accuracy: 0.6774 - val_loss: 0.8557
# Epoch 10/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.5612 - loss: 1.2185 - val_accuracy: 0.7032 - val_loss: 0.8099
# Epoch 11/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.5509 - loss: 1.2252 - val_accuracy: 0.7032 - val_loss: 0.8062
# Epoch 12/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 330ms/step - accuracy: 0.5453 - loss: 1.3100 - val_accuracy: 0.7161 - val_loss: 0.7956
# Epoch 13/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.5531 - loss: 1.0972 - val_accuracy: 0.7290 - val_loss: 0.7726
# Epoch 14/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.6356 - loss: 1.0806 - val_accuracy: 0.7290 - val_loss: 0.7523
# Epoch 15/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.5610 - loss: 1.1772 - val_accuracy: 0.7226 - val_loss: 0.7289
# Epoch 16/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.6163 - loss: 1.0087 - val_accuracy: 0.7355 - val_loss: 0.7300
# Epoch 17/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 340ms/step - accuracy: 0.6169 - loss: 1.0236 - val_accuracy: 0.7290 - val_loss: 0.7285
# Epoch 18/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.5963 - loss: 0.9862 - val_accuracy: 0.7355 - val_loss: 0.7028
# Epoch 19/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 405ms/step - accuracy: 0.6370 - loss: 0.9735 - val_accuracy: 0.7290 - val_loss: 0.6944
# Epoch 20/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.6206 - loss: 0.9438 - val_accuracy: 0.7419 - val_loss: 0.6821
# Epoch 21/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.6464 - loss: 0.9906 - val_accuracy: 0.7419 - val_loss: 0.6725
# Epoch 22/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 338ms/step - accuracy: 0.6259 - loss: 1.0419 - val_accuracy: 0.7419 - val_loss: 0.6669
# Epoch 23/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 381ms/step - accuracy: 0.6458 - loss: 0.9599 - val_accuracy: 0.7548 - val_loss: 0.6535
# Epoch 24/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.6530 - loss: 0.9590 - val_accuracy: 0.7419 - val_loss: 0.6498
# Epoch 25/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.6565 - loss: 0.8988 - val_accuracy: 0.7419 - val_loss: 0.6569
# Epoch 26/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.6774 - loss: 0.9388 - val_accuracy: 0.7484 - val_loss: 0.6701
# Epoch 27/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.6463 - loss: 0.9862 - val_accuracy: 0.7290 - val_loss: 0.6866
# Epoch 28/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 381ms/step - accuracy: 0.6672 - loss: 0.8347 - val_accuracy: 0.7419 - val_loss: 0.6922
# Epoch 29/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.6807 - loss: 0.8896 - val_accuracy: 0.7290 - val_loss: 0.6771
# Epoch 30/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step - accuracy: 0.6496 - loss: 0.8950 - val_accuracy: 0.7484 - val_loss: 0.6741
# Epoch 31/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.6476 - loss: 0.9323 - val_accuracy: 0.7419 - val_loss: 0.6746
# Epoch 32/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7018 - loss: 0.8018 - val_accuracy: 0.7355 - val_loss: 0.6764
# Epoch 33/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.6881 - loss: 0.8201 - val_accuracy: 0.7355 - val_loss: 0.6843
# Epoch 34/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.6751 - loss: 0.8515 - val_accuracy: 0.7419 - val_loss: 0.6807
# Epoch 35/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 378ms/step - accuracy: 0.6905 - loss: 0.7759 - val_accuracy: 0.7613 - val_loss: 0.6681
# Epoch 36/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.6781 - loss: 0.8414 - val_accuracy: 0.7419 - val_loss: 0.6582
# Epoch 37/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.6695 - loss: 0.8596 - val_accuracy: 0.7419 - val_loss: 0.6635
# Epoch 38/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.6867 - loss: 0.7925 - val_accuracy: 0.7484 - val_loss: 0.6599
# Epoch 39/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.6542 - loss: 0.8235 - val_accuracy: 0.7548 - val_loss: 0.6597
# Epoch 40/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.7159 - loss: 0.7848 - val_accuracy: 0.7613 - val_loss: 0.6555
# Epoch 41/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.6936 - loss: 0.7594 - val_accuracy: 0.7742 - val_loss: 0.6645
# Epoch 42/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.6691 - loss: 0.8572 - val_accuracy: 0.7484 - val_loss: 0.6780
# Epoch 43/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 381ms/step - accuracy: 0.7059 - loss: 0.7663 - val_accuracy: 0.7484 - val_loss: 0.6854
# Epoch 44/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.6723 - loss: 0.8346 - val_accuracy: 0.7226 - val_loss: 0.6783
# Epoch 45/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 409ms/step - accuracy: 0.7220 - loss: 0.7413 - val_accuracy: 0.7226 - val_loss: 0.6769
# Epoch 46/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 340ms/step - accuracy: 0.7014 - loss: 0.7712 - val_accuracy: 0.7161 - val_loss: 0.6722
# Epoch 47/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.7100 - loss: 0.7398 - val_accuracy: 0.7355 - val_loss: 0.6713
# Epoch 48/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7216 - loss: 0.7354 - val_accuracy: 0.7355 - val_loss: 0.6717
# Epoch 49/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.6977 - loss: 0.7641 - val_accuracy: 0.7226 - val_loss: 0.6659
# Epoch 50/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7060 - loss: 0.7343 - val_accuracy: 0.7419 - val_loss: 0.6672
# Epoch 51/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.7161 - loss: 0.7292 - val_accuracy: 0.7226 - val_loss: 0.6702
# Epoch 52/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 387ms/step - accuracy: 0.6919 - loss: 0.7955 - val_accuracy: 0.7290 - val_loss: 0.6604
# Epoch 53/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7163 - loss: 0.6982 - val_accuracy: 0.7161 - val_loss: 0.6578
# Epoch 54/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 334ms/step - accuracy: 0.6773 - loss: 0.8232 - val_accuracy: 0.7161 - val_loss: 0.6532
# Epoch 55/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 380ms/step - accuracy: 0.6869 - loss: 0.7632 - val_accuracy: 0.7355 - val_loss: 0.6485
# Epoch 56/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.7257 - loss: 0.7016 - val_accuracy: 0.7290 - val_loss: 0.6562
# Epoch 57/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.7325 - loss: 0.6922 - val_accuracy: 0.7226 - val_loss: 0.6548
# Epoch 58/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.7310 - loss: 0.7258 - val_accuracy: 0.7419 - val_loss: 0.6480
# Epoch 59/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7610 - loss: 0.6697 - val_accuracy: 0.7355 - val_loss: 0.6492
# Epoch 60/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.7526 - loss: 0.6654 - val_accuracy: 0.7226 - val_loss: 0.6528
# Epoch 61/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 387ms/step - accuracy: 0.7648 - loss: 0.6684 - val_accuracy: 0.7226 - val_loss: 0.6587
# Epoch 62/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7447 - loss: 0.6747 - val_accuracy: 0.7161 - val_loss: 0.6585
# Epoch 63/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.7214 - loss: 0.6596 - val_accuracy: 0.7097 - val_loss: 0.6596
# Epoch 64/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 347ms/step - accuracy: 0.6760 - loss: 0.7813 - val_accuracy: 0.7161 - val_loss: 0.6492
# Epoch 65/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.7409 - loss: 0.6607 - val_accuracy: 0.7355 - val_loss: 0.6538
# Epoch 66/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.7504 - loss: 0.6680 - val_accuracy: 0.7419 - val_loss: 0.6511
# Epoch 67/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.7415 - loss: 0.7408 - val_accuracy: 0.7355 - val_loss: 0.6581
# Epoch 68/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.6777 - loss: 0.7618 - val_accuracy: 0.7290 - val_loss: 0.6639
# Epoch 69/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.7261 - loss: 0.6957 - val_accuracy: 0.7419 - val_loss: 0.6578
# Epoch 70/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.7214 - loss: 0.7189 - val_accuracy: 0.7355 - val_loss: 0.6566
# Epoch 71/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.6866 - loss: 0.7838 - val_accuracy: 0.7355 - val_loss: 0.6511
# Epoch 72/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.7649 - loss: 0.5974 - val_accuracy: 0.7355 - val_loss: 0.6422
# Epoch 73/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.6829 - loss: 0.7313 - val_accuracy: 0.7419 - val_loss: 0.6482
# Epoch 74/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.7080 - loss: 0.7830 - val_accuracy: 0.7290 - val_loss: 0.6500
# Epoch 75/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 435ms/step - accuracy: 0.7390 - loss: 0.7050 - val_accuracy: 0.7290 - val_loss: 0.6458
# Epoch 76/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.7396 - loss: 0.6518 - val_accuracy: 0.7226 - val_loss: 0.6432
# Epoch 77/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.7554 - loss: 0.6421 - val_accuracy: 0.7226 - val_loss: 0.6367
# Epoch 78/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 379ms/step - accuracy: 0.7116 - loss: 0.7085 - val_accuracy: 0.7355 - val_loss: 0.6378
# Epoch 79/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 344ms/step - accuracy: 0.7426 - loss: 0.6745 - val_accuracy: 0.7484 - val_loss: 0.6361
# Epoch 80/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 376ms/step - accuracy: 0.7406 - loss: 0.6656 - val_accuracy: 0.7548 - val_loss: 0.6340
# Epoch 81/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.7611 - loss: 0.6389 - val_accuracy: 0.7613 - val_loss: 0.6296
# Epoch 82/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7293 - loss: 0.6552 - val_accuracy: 0.7677 - val_loss: 0.6301
# Epoch 83/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.7169 - loss: 0.6850 - val_accuracy: 0.7548 - val_loss: 0.6353
# Epoch 84/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.7350 - loss: 0.7073 - val_accuracy: 0.7548 - val_loss: 0.6424
# Epoch 85/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 379ms/step - accuracy: 0.7296 - loss: 0.6405 - val_accuracy: 0.7419 - val_loss: 0.6452
# Epoch 86/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.7473 - loss: 0.6630 - val_accuracy: 0.7419 - val_loss: 0.6470
# Epoch 87/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 338ms/step - accuracy: 0.7237 - loss: 0.6545 - val_accuracy: 0.7484 - val_loss: 0.6529
# Epoch 88/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.7529 - loss: 0.6549 - val_accuracy: 0.7548 - val_loss: 0.6548
# Epoch 89/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.7122 - loss: 0.6532 - val_accuracy: 0.7355 - val_loss: 0.6574
# Epoch 90/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 372ms/step - accuracy: 0.7832 - loss: 0.6037 - val_accuracy: 0.7290 - val_loss: 0.6541
# Epoch 91/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.7308 - loss: 0.6809 - val_accuracy: 0.7290 - val_loss: 0.6476
# Epoch 92/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 344ms/step - accuracy: 0.7257 - loss: 0.7088 - val_accuracy: 0.7290 - val_loss: 0.6493
# Epoch 93/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.7324 - loss: 0.6437 - val_accuracy: 0.7290 - val_loss: 0.6514
# Epoch 94/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 341ms/step - accuracy: 0.7446 - loss: 0.6145 - val_accuracy: 0.7290 - val_loss: 0.6527
# Epoch 95/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 378ms/step - accuracy: 0.7478 - loss: 0.6408 - val_accuracy: 0.7032 - val_loss: 0.6563
# Epoch 96/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.7480 - loss: 0.6059 - val_accuracy: 0.7161 - val_loss: 0.6532
# Epoch 97/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.7806 - loss: 0.5467 - val_accuracy: 0.7226 - val_loss: 0.6606
# Epoch 98/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.7395 - loss: 0.6200 - val_accuracy: 0.7290 - val_loss: 0.6634
# Epoch 99/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 365ms/step - accuracy: 0.7638 - loss: 0.6825 - val_accuracy: 0.7226 - val_loss: 0.6578
# Epoch 100/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.7610 - loss: 0.6054 - val_accuracy: 0.7355 - val_loss: 0.6531
# Epoch 101/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.7174 - loss: 0.6654 - val_accuracy: 0.7484 - val_loss: 0.6561
# Epoch 102/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 343ms/step - accuracy: 0.7469 - loss: 0.5909 - val_accuracy: 0.7484 - val_loss: 0.6637
# Epoch 103/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.7543 - loss: 0.6252 - val_accuracy: 0.7548 - val_loss: 0.6572
# Epoch 104/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 0.7746 - loss: 0.5893 - val_accuracy: 0.7290 - val_loss: 0.6571
# Epoch 105/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7711 - loss: 0.6215 - val_accuracy: 0.7290 - val_loss: 0.6576
# Epoch 106/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.7515 - loss: 0.6043 - val_accuracy: 0.7355 - val_loss: 0.6585
# Epoch 107/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7642 - loss: 0.5999 - val_accuracy: 0.7226 - val_loss: 0.6515
# Epoch 108/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.6734 - loss: 0.7885 - val_accuracy: 0.7226 - val_loss: 0.6487
# Epoch 109/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.7736 - loss: 0.5877 - val_accuracy: 0.7290 - val_loss: 0.6429
# Epoch 110/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.7951 - loss: 0.5702 - val_accuracy: 0.7355 - val_loss: 0.6446
# Epoch 111/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.7919 - loss: 0.5576 - val_accuracy: 0.7290 - val_loss: 0.6495
# Epoch 112/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.7402 - loss: 0.6154 - val_accuracy: 0.7226 - val_loss: 0.6598
# Epoch 113/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.7684 - loss: 0.5740 - val_accuracy: 0.7097 - val_loss: 0.6549
# Epoch 114/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.7591 - loss: 0.5836 - val_accuracy: 0.7161 - val_loss: 0.6545
# Epoch 115/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 337ms/step - accuracy: 0.7488 - loss: 0.6219 - val_accuracy: 0.7226 - val_loss: 0.6475
# Epoch 116/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.7429 - loss: 0.6391 - val_accuracy: 0.7226 - val_loss: 0.6417
# Epoch 117/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.7700 - loss: 0.5657 - val_accuracy: 0.7355 - val_loss: 0.6375
# Epoch 118/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.7331 - loss: 0.6787 - val_accuracy: 0.7355 - val_loss: 0.6372
# Epoch 119/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.7699 - loss: 0.5933 - val_accuracy: 0.7290 - val_loss: 0.6305
# Epoch 120/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 343ms/step - accuracy: 0.7650 - loss: 0.5861 - val_accuracy: 0.7097 - val_loss: 0.6322
# Epoch 121/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.7514 - loss: 0.6181 - val_accuracy: 0.7032 - val_loss: 0.6360
# Epoch 122/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 346ms/step - accuracy: 0.8014 - loss: 0.5228 - val_accuracy: 0.7097 - val_loss: 0.6419
# Epoch 123/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7640 - loss: 0.6139 - val_accuracy: 0.7226 - val_loss: 0.6450
# Epoch 124/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.7672 - loss: 0.5928 - val_accuracy: 0.7419 - val_loss: 0.6380
# Epoch 125/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.7679 - loss: 0.6368 - val_accuracy: 0.7290 - val_loss: 0.6404
# Epoch 126/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.7701 - loss: 0.5786 - val_accuracy: 0.7161 - val_loss: 0.6350
# Epoch 127/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 347ms/step - accuracy: 0.7469 - loss: 0.5957 - val_accuracy: 0.7161 - val_loss: 0.6338
# Epoch 128/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 371ms/step - accuracy: 0.8010 - loss: 0.5319 - val_accuracy: 0.7419 - val_loss: 0.6346
# Epoch 129/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 392ms/step - accuracy: 0.8070 - loss: 0.5160 - val_accuracy: 0.7419 - val_loss: 0.6294
# Epoch 130/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 340ms/step - accuracy: 0.7771 - loss: 0.5880 - val_accuracy: 0.7290 - val_loss: 0.6329
# Epoch 131/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.7523 - loss: 0.5921 - val_accuracy: 0.7419 - val_loss: 0.6368
# Epoch 132/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 366ms/step - accuracy: 0.7684 - loss: 0.5652 - val_accuracy: 0.7419 - val_loss: 0.6369
# Epoch 133/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 347ms/step - accuracy: 0.7474 - loss: 0.6141 - val_accuracy: 0.7419 - val_loss: 0.6336
# Epoch 134/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.7973 - loss: 0.5271 - val_accuracy: 0.7290 - val_loss: 0.6339
# Epoch 135/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 335ms/step - accuracy: 0.8023 - loss: 0.5157 - val_accuracy: 0.7548 - val_loss: 0.6362
# Epoch 136/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.7706 - loss: 0.5544 - val_accuracy: 0.7548 - val_loss: 0.6362
# Epoch 137/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.7941 - loss: 0.5576 - val_accuracy: 0.7548 - val_loss: 0.6378
# Epoch 138/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 340ms/step - accuracy: 0.7784 - loss: 0.5735 - val_accuracy: 0.7613 - val_loss: 0.6339
# Epoch 139/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.8132 - loss: 0.5100 - val_accuracy: 0.7419 - val_loss: 0.6381
# Epoch 140/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 338ms/step - accuracy: 0.7399 - loss: 0.5914 - val_accuracy: 0.7290 - val_loss: 0.6403
# Epoch 141/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 407ms/step - accuracy: 0.7696 - loss: 0.5620 - val_accuracy: 0.7290 - val_loss: 0.6400
# Epoch 142/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.7639 - loss: 0.5738 - val_accuracy: 0.7419 - val_loss: 0.6318
# Epoch 143/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.7504 - loss: 0.6089 - val_accuracy: 0.7484 - val_loss: 0.6319
# Epoch 144/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.7849 - loss: 0.5657 - val_accuracy: 0.7484 - val_loss: 0.6325
# Epoch 145/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.7779 - loss: 0.5794 - val_accuracy: 0.7419 - val_loss: 0.6303
# Epoch 146/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - accuracy: 0.7886 - loss: 0.5744 - val_accuracy: 0.7548 - val_loss: 0.6295
# Epoch 147/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 392ms/step - accuracy: 0.8036 - loss: 0.5488 - val_accuracy: 0.7484 - val_loss: 0.6280
# Epoch 148/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - accuracy: 0.7849 - loss: 0.5463 - val_accuracy: 0.7484 - val_loss: 0.6230
# Epoch 149/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 405ms/step - accuracy: 0.7896 - loss: 0.5445 - val_accuracy: 0.7290 - val_loss: 0.6200
# Epoch 150/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.7607 - loss: 0.6060 - val_accuracy: 0.7419 - val_loss: 0.6204

# %%
# Evaluate the model on test data
test_loss, test_accuracy = mobileNet_model.evaluate(test_generator, verbose=0)
train_loss, train_accuracy = mobileNet_model.evaluate(train_generator, verbose=0)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Make predictions
test_generator.reset()
predictions = mobileNet_model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Plot training history
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Train Accuracy: 88.29%
# Test Accuracy: 74.19%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Load VGG16 pretrained on ImageNet
vgg_base = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
vgg_base.trainable = False  # Freeze the base layers

# Custom classifier
inputs = Input(shape=(224, 224, 3))
x = vgg_base(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
outputs = Dense(train_generator.num_classes, activation='softmax')(x)

vgg_model = Model(inputs, outputs)
vgg_model.compile(optimizer=Adam(learning_rate=0.0005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# Train VGG16 model
vgg_history = vgg_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=150
)
# Out:
# Found 615 images belonging to 4 classes.
# Found 155 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.2337 - loss: 2.3729 - val_accuracy: 0.1290 - val_loss: 1.3952
# Epoch 2/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.3411 - loss: 2.1564 - val_accuracy: 0.4323 - val_loss: 1.2878
# Epoch 3/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 466ms/step - accuracy: 0.3928 - loss: 1.8649 - val_accuracy: 0.6194 - val_loss: 1.1746
# Epoch 4/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.3997 - loss: 1.7584 - val_accuracy: 0.6387 - val_loss: 1.1171
# Epoch 5/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.4028 - loss: 1.7951 - val_accuracy: 0.6323 - val_loss: 1.0594
# Epoch 6/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 489ms/step - accuracy: 0.4986 - loss: 1.4468 - val_accuracy: 0.6323 - val_loss: 1.0178
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 494ms/step - accuracy: 0.5052 - loss: 1.4229 - val_accuracy: 0.6452 - val_loss: 1.0089
# Epoch 8/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 445ms/step - accuracy: 0.5393 - loss: 1.3806 - val_accuracy: 0.6452 - val_loss: 0.9943
# Epoch 9/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.4711 - loss: 1.5449 - val_accuracy: 0.6452 - val_loss: 0.9842
# Epoch 10/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.4886 - loss: 1.4587 - val_accuracy: 0.6452 - val_loss: 0.9796
# Epoch 11/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 484ms/step - accuracy: 0.5090 - loss: 1.4442 - val_accuracy: 0.6452 - val_loss: 0.9737
# Epoch 12/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 470ms/step - accuracy: 0.5405 - loss: 1.2934 - val_accuracy: 0.6323 - val_loss: 0.9736
# Epoch 13/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 447ms/step - accuracy: 0.5393 - loss: 1.2402 - val_accuracy: 0.6323 - val_loss: 0.9730
# Epoch 14/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.5683 - loss: 1.1965 - val_accuracy: 0.6323 - val_loss: 0.9736
# Epoch 15/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.5549 - loss: 1.2621 - val_accuracy: 0.6323 - val_loss: 0.9770
# Epoch 16/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.5572 - loss: 1.1503 - val_accuracy: 0.6258 - val_loss: 0.9788
# Epoch 17/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 441ms/step - accuracy: 0.5856 - loss: 1.1721 - val_accuracy: 0.6258 - val_loss: 0.9954
# Epoch 18/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.5925 - loss: 1.1202 - val_accuracy: 0.6387 - val_loss: 1.0011
# Epoch 19/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.6149 - loss: 0.9966 - val_accuracy: 0.6710 - val_loss: 0.9816
# Epoch 20/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.5753 - loss: 1.1010 - val_accuracy: 0.6710 - val_loss: 0.9713
# Epoch 21/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 468ms/step - accuracy: 0.6010 - loss: 1.1063 - val_accuracy: 0.6710 - val_loss: 0.9723
# Epoch 22/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 445ms/step - accuracy: 0.5935 - loss: 1.1373 - val_accuracy: 0.6774 - val_loss: 0.9573
# Epoch 23/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.6150 - loss: 1.1114 - val_accuracy: 0.6839 - val_loss: 0.9571
# Epoch 24/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.6121 - loss: 1.0173 - val_accuracy: 0.6903 - val_loss: 0.9546
# Epoch 25/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.6199 - loss: 0.9527 - val_accuracy: 0.6968 - val_loss: 0.9389
# Epoch 26/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.6290 - loss: 1.0253 - val_accuracy: 0.6968 - val_loss: 0.9383
# Epoch 27/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 510ms/step - accuracy: 0.6183 - loss: 1.0331 - val_accuracy: 0.6968 - val_loss: 0.9404
# Epoch 28/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 497ms/step - accuracy: 0.6211 - loss: 0.9249 - val_accuracy: 0.6968 - val_loss: 0.9441
# Epoch 29/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.6466 - loss: 1.0112 - val_accuracy: 0.6968 - val_loss: 0.9611
# Epoch 30/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 479ms/step - accuracy: 0.6004 - loss: 1.0595 - val_accuracy: 0.6839 - val_loss: 0.9597
# Epoch 31/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.6624 - loss: 0.9156 - val_accuracy: 0.6903 - val_loss: 0.9690
# Epoch 32/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 496ms/step - accuracy: 0.6312 - loss: 0.9434 - val_accuracy: 0.6903 - val_loss: 0.9549
# Epoch 33/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.6282 - loss: 0.9840 - val_accuracy: 0.6903 - val_loss: 0.9362
# Epoch 34/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.6421 - loss: 0.9767 - val_accuracy: 0.6968 - val_loss: 0.9420
# Epoch 35/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 468ms/step - accuracy: 0.6322 - loss: 0.9994 - val_accuracy: 0.6903 - val_loss: 0.9323
# Epoch 36/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 453ms/step - accuracy: 0.6355 - loss: 0.9504 - val_accuracy: 0.6839 - val_loss: 0.9249
# Epoch 37/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.6446 - loss: 0.9203 - val_accuracy: 0.6968 - val_loss: 0.9159
# Epoch 38/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 507ms/step - accuracy: 0.6111 - loss: 0.9586 - val_accuracy: 0.6903 - val_loss: 0.8979
# Epoch 39/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.6236 - loss: 0.9225 - val_accuracy: 0.7097 - val_loss: 0.9003
# Epoch 40/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 449ms/step - accuracy: 0.6673 - loss: 0.9190 - val_accuracy: 0.6903 - val_loss: 0.8736
# Epoch 41/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 462ms/step - accuracy: 0.6544 - loss: 0.8925 - val_accuracy: 0.6903 - val_loss: 0.8731
# Epoch 42/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.6484 - loss: 0.9700 - val_accuracy: 0.6903 - val_loss: 0.8852
# Epoch 43/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.6209 - loss: 1.0126 - val_accuracy: 0.6839 - val_loss: 0.8864
# Epoch 44/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 470ms/step - accuracy: 0.6324 - loss: 0.9615 - val_accuracy: 0.6839 - val_loss: 0.8761
# Epoch 45/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.6446 - loss: 0.8926 - val_accuracy: 0.6774 - val_loss: 0.8722
# Epoch 46/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.6458 - loss: 0.8773 - val_accuracy: 0.6839 - val_loss: 0.8810
# Epoch 47/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.6475 - loss: 0.8825 - val_accuracy: 0.6839 - val_loss: 0.8781
# Epoch 48/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.6377 - loss: 0.8854 - val_accuracy: 0.6774 - val_loss: 0.8888
# Epoch 49/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 453ms/step - accuracy: 0.6603 - loss: 0.8876 - val_accuracy: 0.6839 - val_loss: 0.8880
# Epoch 50/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 486ms/step - accuracy: 0.6709 - loss: 0.8724 - val_accuracy: 0.6839 - val_loss: 0.8821
# Epoch 51/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.6901 - loss: 0.8047 - val_accuracy: 0.6839 - val_loss: 0.8844
# Epoch 52/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 494ms/step - accuracy: 0.6725 - loss: 0.8517 - val_accuracy: 0.6774 - val_loss: 0.8796
# Epoch 53/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.6643 - loss: 0.9288 - val_accuracy: 0.6710 - val_loss: 0.8735
# Epoch 54/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 452ms/step - accuracy: 0.6471 - loss: 0.8791 - val_accuracy: 0.6710 - val_loss: 0.8922
# Epoch 55/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 481ms/step - accuracy: 0.6516 - loss: 0.9549 - val_accuracy: 0.6839 - val_loss: 0.9061
# Epoch 56/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 496ms/step - accuracy: 0.6437 - loss: 0.8419 - val_accuracy: 0.6774 - val_loss: 0.8946
# Epoch 57/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.6542 - loss: 0.8764 - val_accuracy: 0.6839 - val_loss: 0.9047
# Epoch 58/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 477ms/step - accuracy: 0.6709 - loss: 0.8192 - val_accuracy: 0.6839 - val_loss: 0.9048
# Epoch 59/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 472ms/step - accuracy: 0.6654 - loss: 0.8830 - val_accuracy: 0.6968 - val_loss: 0.9123
# Epoch 60/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.6814 - loss: 0.8209 - val_accuracy: 0.7097 - val_loss: 0.9252
# Epoch 61/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 495ms/step - accuracy: 0.6649 - loss: 0.8873 - val_accuracy: 0.7032 - val_loss: 0.9242
# Epoch 62/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.6856 - loss: 0.7663 - val_accuracy: 0.7032 - val_loss: 0.9239
# Epoch 63/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.6694 - loss: 0.8097 - val_accuracy: 0.6839 - val_loss: 0.9087
# Epoch 64/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 454ms/step - accuracy: 0.6970 - loss: 0.8344 - val_accuracy: 0.6903 - val_loss: 0.8967
# Epoch 65/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.6562 - loss: 0.8497 - val_accuracy: 0.7032 - val_loss: 0.8928
# Epoch 66/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.6622 - loss: 0.8324 - val_accuracy: 0.7032 - val_loss: 0.8944
# Epoch 67/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 482ms/step - accuracy: 0.7254 - loss: 0.7560 - val_accuracy: 0.7032 - val_loss: 0.8787
# Epoch 68/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 448ms/step - accuracy: 0.6677 - loss: 0.8354 - val_accuracy: 0.6903 - val_loss: 0.8690
# Epoch 69/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 447ms/step - accuracy: 0.6713 - loss: 0.8542 - val_accuracy: 0.6968 - val_loss: 0.8683
# Epoch 70/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 481ms/step - accuracy: 0.6882 - loss: 0.8156 - val_accuracy: 0.7097 - val_loss: 0.8736
# Epoch 71/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 506ms/step - accuracy: 0.7037 - loss: 0.7612 - val_accuracy: 0.6968 - val_loss: 0.8735
# Epoch 72/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 481ms/step - accuracy: 0.6721 - loss: 0.8263 - val_accuracy: 0.7032 - val_loss: 0.8788
# Epoch 73/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.6546 - loss: 0.8217 - val_accuracy: 0.6903 - val_loss: 0.8812
# Epoch 74/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 473ms/step - accuracy: 0.6834 - loss: 0.7969 - val_accuracy: 0.6903 - val_loss: 0.8812
# Epoch 75/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 478ms/step - accuracy: 0.7283 - loss: 0.7520 - val_accuracy: 0.6903 - val_loss: 0.8694
# Epoch 76/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 484ms/step - accuracy: 0.6985 - loss: 0.7670 - val_accuracy: 0.7032 - val_loss: 0.8686
# Epoch 77/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.6661 - loss: 0.8155 - val_accuracy: 0.7032 - val_loss: 0.8777
# Epoch 78/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 444ms/step - accuracy: 0.6953 - loss: 0.8095 - val_accuracy: 0.6968 - val_loss: 0.8981
# Epoch 79/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.6793 - loss: 0.8414 - val_accuracy: 0.7097 - val_loss: 0.8857
# Epoch 80/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 483ms/step - accuracy: 0.6748 - loss: 0.8334 - val_accuracy: 0.7032 - val_loss: 0.8764
# Epoch 81/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 473ms/step - accuracy: 0.6751 - loss: 0.7403 - val_accuracy: 0.7032 - val_loss: 0.8649
# Epoch 82/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 456ms/step - accuracy: 0.7012 - loss: 0.7543 - val_accuracy: 0.7032 - val_loss: 0.8539
# Epoch 83/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 489ms/step - accuracy: 0.7011 - loss: 0.7498 - val_accuracy: 0.6968 - val_loss: 0.8614
# Epoch 84/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.6532 - loss: 0.8454 - val_accuracy: 0.7161 - val_loss: 0.8645
# Epoch 85/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.6485 - loss: 0.8477 - val_accuracy: 0.7290 - val_loss: 0.8648
# Epoch 86/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 478ms/step - accuracy: 0.6992 - loss: 0.7751 - val_accuracy: 0.7161 - val_loss: 0.8694
# Epoch 87/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 458ms/step - accuracy: 0.6992 - loss: 0.7872 - val_accuracy: 0.7161 - val_loss: 0.8703
# Epoch 88/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 492ms/step - accuracy: 0.6885 - loss: 0.7365 - val_accuracy: 0.7097 - val_loss: 0.8634
# Epoch 89/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.6549 - loss: 0.8442 - val_accuracy: 0.7161 - val_loss: 0.8697
# Epoch 90/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.6487 - loss: 0.8260 - val_accuracy: 0.7032 - val_loss: 0.8670
# Epoch 91/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 492ms/step - accuracy: 0.6874 - loss: 0.7705 - val_accuracy: 0.7032 - val_loss: 0.8624
# Epoch 92/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 448ms/step - accuracy: 0.7074 - loss: 0.7346 - val_accuracy: 0.7032 - val_loss: 0.8717
# Epoch 93/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 495ms/step - accuracy: 0.6981 - loss: 0.7717 - val_accuracy: 0.7032 - val_loss: 0.8759
# Epoch 94/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.6901 - loss: 0.7770 - val_accuracy: 0.7097 - val_loss: 0.8759
# Epoch 95/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 496ms/step - accuracy: 0.6557 - loss: 0.8092 - val_accuracy: 0.6968 - val_loss: 0.8761
# Epoch 96/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 459ms/step - accuracy: 0.6930 - loss: 0.7449 - val_accuracy: 0.6968 - val_loss: 0.8758
# Epoch 97/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 458ms/step - accuracy: 0.7150 - loss: 0.7293 - val_accuracy: 0.6903 - val_loss: 0.8698
# Epoch 98/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.7401 - loss: 0.7672 - val_accuracy: 0.7032 - val_loss: 0.8710
# Epoch 99/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.6913 - loss: 0.7844 - val_accuracy: 0.7097 - val_loss: 0.8664
# Epoch 100/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 492ms/step - accuracy: 0.6736 - loss: 0.8112 - val_accuracy: 0.7097 - val_loss: 0.8734
# Epoch 101/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 472ms/step - accuracy: 0.7017 - loss: 0.8293 - val_accuracy: 0.7032 - val_loss: 0.8804
# Epoch 102/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 472ms/step - accuracy: 0.7043 - loss: 0.7723 - val_accuracy: 0.6903 - val_loss: 0.8719
# Epoch 103/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.6885 - loss: 0.7319 - val_accuracy: 0.6903 - val_loss: 0.8850
# Epoch 104/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.7089 - loss: 0.7543 - val_accuracy: 0.6903 - val_loss: 0.8876
# Epoch 105/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 472ms/step - accuracy: 0.7215 - loss: 0.7248 - val_accuracy: 0.6839 - val_loss: 0.8795
# Epoch 106/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 451ms/step - accuracy: 0.7176 - loss: 0.7593 - val_accuracy: 0.6839 - val_loss: 0.8854
# Epoch 107/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.6653 - loss: 0.7985 - val_accuracy: 0.6839 - val_loss: 0.8833
# Epoch 108/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 494ms/step - accuracy: 0.6373 - loss: 0.8476 - val_accuracy: 0.7032 - val_loss: 0.8695
# Epoch 109/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.7409 - loss: 0.7135 - val_accuracy: 0.6903 - val_loss: 0.8793
# Epoch 110/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 452ms/step - accuracy: 0.7068 - loss: 0.6952 - val_accuracy: 0.6839 - val_loss: 0.8942
# Epoch 111/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.7323 - loss: 0.6964 - val_accuracy: 0.6774 - val_loss: 0.8824
# Epoch 112/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 485ms/step - accuracy: 0.7068 - loss: 0.7159 - val_accuracy: 0.6645 - val_loss: 0.8862
# Epoch 113/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.6834 - loss: 0.7855 - val_accuracy: 0.6774 - val_loss: 0.8782
# Epoch 114/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.6705 - loss: 0.7620 - val_accuracy: 0.6903 - val_loss: 0.8696
# Epoch 115/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 453ms/step - accuracy: 0.7339 - loss: 0.7131 - val_accuracy: 0.6968 - val_loss: 0.8750
# Epoch 116/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 476ms/step - accuracy: 0.7322 - loss: 0.6737 - val_accuracy: 0.6839 - val_loss: 0.8783
# Epoch 117/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.7051 - loss: 0.8124 - val_accuracy: 0.6903 - val_loss: 0.8761
# Epoch 118/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.6959 - loss: 0.7331 - val_accuracy: 0.6968 - val_loss: 0.8819
# Epoch 119/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 462ms/step - accuracy: 0.7004 - loss: 0.7443 - val_accuracy: 0.6968 - val_loss: 0.8854
# Epoch 120/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 454ms/step - accuracy: 0.6795 - loss: 0.8091 - val_accuracy: 0.7032 - val_loss: 0.8762
# Epoch 121/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 494ms/step - accuracy: 0.7288 - loss: 0.7365 - val_accuracy: 0.6968 - val_loss: 0.8623
# Epoch 122/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 516ms/step - accuracy: 0.7234 - loss: 0.7040 - val_accuracy: 0.6968 - val_loss: 0.8628
# Epoch 123/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.6959 - loss: 0.7894 - val_accuracy: 0.6968 - val_loss: 0.8631
# Epoch 124/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 466ms/step - accuracy: 0.6974 - loss: 0.7306 - val_accuracy: 0.7032 - val_loss: 0.8649
# Epoch 125/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 458ms/step - accuracy: 0.6891 - loss: 0.7883 - val_accuracy: 0.6968 - val_loss: 0.8695
# Epoch 126/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 487ms/step - accuracy: 0.7451 - loss: 0.7140 - val_accuracy: 0.6903 - val_loss: 0.8683
# Epoch 127/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 488ms/step - accuracy: 0.7055 - loss: 0.7464 - val_accuracy: 0.7097 - val_loss: 0.8659
# Epoch 128/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 489ms/step - accuracy: 0.7020 - loss: 0.7290 - val_accuracy: 0.6968 - val_loss: 0.8583
# Epoch 129/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 452ms/step - accuracy: 0.7646 - loss: 0.6632 - val_accuracy: 0.6903 - val_loss: 0.8609
# Epoch 130/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 463ms/step - accuracy: 0.6867 - loss: 0.7744 - val_accuracy: 0.6839 - val_loss: 0.8628
# Epoch 131/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.7222 - loss: 0.7398 - val_accuracy: 0.6968 - val_loss: 0.8651
# Epoch 132/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 489ms/step - accuracy: 0.7001 - loss: 0.7815 - val_accuracy: 0.6968 - val_loss: 0.8729
# Epoch 133/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 489ms/step - accuracy: 0.7294 - loss: 0.6985 - val_accuracy: 0.6968 - val_loss: 0.8760
# Epoch 134/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.6658 - loss: 0.8126 - val_accuracy: 0.6903 - val_loss: 0.8873
# Epoch 135/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.7216 - loss: 0.7173 - val_accuracy: 0.6710 - val_loss: 0.8913
# Epoch 136/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 491ms/step - accuracy: 0.6754 - loss: 0.7323 - val_accuracy: 0.6903 - val_loss: 0.8714
# Epoch 137/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 499ms/step - accuracy: 0.7155 - loss: 0.7179 - val_accuracy: 0.6968 - val_loss: 0.8676
# Epoch 138/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 471ms/step - accuracy: 0.7151 - loss: 0.6868 - val_accuracy: 0.6903 - val_loss: 0.8718
# Epoch 139/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 456ms/step - accuracy: 0.7132 - loss: 0.7116 - val_accuracy: 0.6839 - val_loss: 0.8688
# Epoch 140/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 498ms/step - accuracy: 0.7351 - loss: 0.6653 - val_accuracy: 0.6774 - val_loss: 0.8817
# Epoch 141/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 497ms/step - accuracy: 0.7191 - loss: 0.7012 - val_accuracy: 0.6903 - val_loss: 0.8742
# Epoch 142/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.7240 - loss: 0.7037 - val_accuracy: 0.6839 - val_loss: 0.8604
# Epoch 143/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 450ms/step - accuracy: 0.7302 - loss: 0.6831 - val_accuracy: 0.6839 - val_loss: 0.8662
# Epoch 144/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.6752 - loss: 0.7925 - val_accuracy: 0.6839 - val_loss: 0.8743
# Epoch 145/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 495ms/step - accuracy: 0.6845 - loss: 0.7432 - val_accuracy: 0.6774 - val_loss: 0.8767
# Epoch 146/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 499ms/step - accuracy: 0.7235 - loss: 0.7267 - val_accuracy: 0.6903 - val_loss: 0.8791
# Epoch 147/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 501ms/step - accuracy: 0.7600 - loss: 0.6474 - val_accuracy: 0.6903 - val_loss: 0.8687
# Epoch 148/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 452ms/step - accuracy: 0.7029 - loss: 0.7049 - val_accuracy: 0.6968 - val_loss: 0.8616
# Epoch 149/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 472ms/step - accuracy: 0.7328 - loss: 0.6838 - val_accuracy: 0.6903 - val_loss: 0.8758
# Epoch 150/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 490ms/step - accuracy: 0.6942 - loss: 0.7328 - val_accuracy: 0.6774 - val_loss: 0.8746

# %%
# Evaluate the model on test data
test_loss, test_accuracy = vgg_model.evaluate(test_generator, verbose=0)
train_loss, train_accuracy = vgg_model.evaluate(train_generator, verbose=0)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Make predictions
test_generator.reset()
predictions = vgg_model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Plot training history
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Train Accuracy: 82.28%
# Test Accuracy: 67.74%
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step

# %%
# Evaluate both models
vgg_eval = vgg_model.evaluate(val_generator, verbose=0)
mobilenet_eval = mobileNet_model.evaluate(val_generator, verbose=0)

print(f"VGG16 Validation Accuracy: {vgg_eval[1]*100:.2f}%")
print(f"MobileNetV2 Validation Accuracy: {mobilenet_eval[1]*100:.2f}%")

# Compare training history visually
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['val_accuracy'], label='MobileNetV2')
plt.plot(vgg_history.history['val_accuracy'], label='VGG16')
plt.title('Validation Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['val_loss'], label='MobileNetV2')
plt.plot(vgg_history.history['val_loss'], label='VGG16')
plt.title('Validation Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# VGG16 Validation Accuracy: 67.74%
# MobileNetV2 Validation Accuracy: 74.19%

# %%
# Cell: Predicting Emotion

import cv2
import numpy as np
import matplotlib.pyplot as plt

def predict_emotion(img_path, model, img_size=IMG_SIZE):
    # Load the image
    img = cv2.imread(img_path)
    if img is None:
        raise ValueError("Image not found or cannot be read.")

    # Preprocess image: resize and convert to RGB
    img = cv2.resize(img, img_size)
    if len(img.shape) == 2:
        img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    elif img.shape[2] == 4:
        img = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)

    # Normalize pixel values
    img = img.astype('float32') / 255.0

    # Expand dimensions to fit model input shape
    img_batch = np.expand_dims(img, axis=0)  # Shape: (1, height, width, channels)

    # Predict
    preds = model.predict(img_batch)
    pred_class = np.argmax(preds, axis=1)[0]
    emotion_label = class_labels[pred_class]  # Use class_labels from notebook scope

    # Show result
    plt.imshow(img)
    plt.title(f"Predicted Emotion: {emotion_label}")
    plt.axis('off')
    plt.show()
    print(f"Predicted Emotion: {emotion_label}")

# %%
#Prediction 1
input_path_1 = 'Ntr.jpg'
predict_emotion(input_path_1, mobileNet_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted Emotion: anger

# %%
input_path_2 = 'Rohit.jpg'
predict_emotion(input_path_2, mobileNet_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted Emotion: joy
